# %% [markdown]
# 1.What is a random variable in probability theory?
#
# A random variable is a numerical outcome of a random process or experiment. It maps outcomes from a sample space to real numbers. There are two main types: discrete and continuous.
#
# 2.What are the types of random variables?
#
# Discrete random variables – take on countable values (e.g., number of heads in 10 coin tosses).
#
# Continuous random variables – take on an infinite number of values within a range (e.g., height, temperature).
#
# 3.What is the difference between discrete and continuous distributions?
#
# Discrete distribution describes the probability of outcomes of a discrete random variable.
#
# Continuous distribution describes probabilities using a probability density function (PDF); the probability of a single value is 0, but intervals have probabilities.
#
# 4. What are probability distribution functions (PDF)?
# A Probability Distribution Function gives the probability that a random variable takes a particular value.
#
# For discrete variables, it's the probability mass function (PMF).
#
# For continuous variables, it's the probability density function (PDF).
#
# 5.How do cumulative distribution functions (CDF) differ from PDFs?
#
# A Cumulative Distribution Function (CDF) gives the probability that a random variable is less than or equal to a certain value.
#
# PDF/PMF shows density/probability at a point.
#
# CDF shows accumulated probability up to a point.
#
# 6. What is a discrete uniform distribution?
#
# A discrete uniform distribution assigns equal probability to all possible outcomes in a finite set.
# Example: Rolling a fair die → P(1) = P(2) = … = P(6) = 1/6.
#
# 7. What are the key properties of a Bernoulli distribution?
#
# Two possible outcomes: success (1) and failure (0).
#
# Probability of success =
# 𝑝
# p, failure =
# 1
# −
# 𝑝
# 1−p.
#
# Mean =
# 𝑝
# p, Variance =
# 𝑝
# (
# 1
# −
# 𝑝
# )
# p(1−p).
#
# 8.What is the binomial distribution, and how is it used in probability?
#
# It models the number of successes in
# 𝑛
# n independent Bernoulli trials with success probability
# 𝑝
# p.
# Used in: quality control, surveys, success/failure experiments.
# Formula:
# 𝑃
# (
# 𝑋
# =
# 𝑘
# )
# =
# (
# 𝑛
# 𝑘
# )
# 𝑝
# 𝑘
# (
# 1
# −
# 𝑝
# )
# 𝑛
# −
# 𝑘
# P(X=k)=(
# k
# n
# ​
#  )p
# k
#  (1−p)
# n−k
#
#
# 9. What is the Poisson distribution and where is it applied?
#
# Models the number of events occurring in a fixed interval (time/space) when events occur independently at a constant rate
# 𝜆
# λ.
# Used in: call arrivals, traffic flow, mutation rates.
#
# 10.What is a continuous uniform distribution?
# A distribution where all outcomes in a continuous interval
# [
# 𝑎
# ,
# 𝑏
# ]
# [a,b] are equally likely.
# PDF:
# 𝑓
# (
# 𝑥
# )
# =
# 1
# 𝑏
# −
# 𝑎
# f(x)=
# b−a
# 1
# ​
#   for
# 𝑎
# ≤
# 𝑥
# ≤
# 𝑏
# a≤x≤b
#
# 11.What are the characteristics of a normal distribution?
#
# Bell-shaped, symmetric about the mean
#
# Mean = Median = Mode
#
# Defined by mean
# 𝜇
# μ and standard deviation
# 𝜎
# σ
#
# Follows empirical rule (68-95-99.7)
#
# 12.What is the standard normal distribution, and why is it important?
#
# A normal distribution with mean
# 𝜇
# =
# 0
# μ=0 and standard deviation
# 𝜎
# =
# 1
# σ=1.
# Used to calculate Z-scores and make comparisons across different normal distributions.
#
# 13.What is the Central Limit Theorem (CLT), and why is it critical in statistics?
#
# The CLT states that the sampling distribution of the sample mean approaches a normal distribution as sample size
# 𝑛
# n increases, regardless of the population's distribution.
# Importance: Enables inference using normal distribution even for non-normal populations.
#
# 14.How does the Central Limit Theorem relate to the normal distribution?
# It justifies using the normal distribution to approximate sample means, especially when
# 𝑛
# ≥
# 30
# n≥30. This underpins many statistical tests and confidence intervals.
#
# 15.What is the application of Z statistics in hypothesis testing?
# Z-statistics compare a sample mean to a population mean when the population standard deviation is known.
# Used in Z-tests for evaluating hypotheses, especially for large samples.
# 16.How do you calculate a Z-score, and what does it represent?
# Formula:
# 𝑍
# =
# 𝑋
# −
# 𝜇
# 𝜎
# Z=
# σ
# X−μ
# ​
#
# Represents how many standard deviations
# 𝑋
# X is from the mean
# 𝜇
# μ. Helps standardize and compare across distributions.
#
# 17.What are point estimates and interval estimates in statistics?
#
# Point estimate: Single value estimate of a population parameter (e.g., sample mean).
#
# Interval estimate: Range of values (e.g., confidence interval) likely to contain the parameter.
#
# 18.What is the significance of confidence intervals in statistical analysis?
#
# They provide a range where the true parameter is likely to lie with a certain confidence level (e.g., 95%). More informative than point estimates.
#
# 19.What is the relationship between a Z-score and a confidence interval?
# Z-scores determine the margin of error in confidence intervals for normal distributions:
# CI
# =
# 𝑥
# ˉ
# ±
# 𝑍
# ⋅
# 𝜎
# 𝑛
# CI=
# x
# ˉ
#  ±Z⋅
# n
# ​
#
# σ
# ​
#
#
# 20.How are Z-scores used to compare different distributions?
# Z-scores standardize values, allowing comparison of data from different distributions by expressing values in terms of standard deviations from their means.
#
# 21.What are the assumptions for applying the Central Limit Theorem?
#
# Independent observations
#
# Identically distributed samples
#
# Sufficiently large sample size (usually
# 𝑛
# ≥
# 30
# n≥30)
#
# Finite variance and mean
#
# 22.What is the concept of expected value in a probability distribution?
# The expected value (mean) of a random variable is the long-run average outcome:
#
# Discrete:
# 𝐸
# [
# 𝑋
# ]
# =
# ∑
# 𝑥
# 𝑖
# 𝑃
# (
# 𝑥
# 𝑖
# )
# E[X]=∑x
# i
# ​
#  P(x
# i
# ​
#  )
#
# Continuous:
# 𝐸
# [
# 𝑋
# ]
# =
# ∫
# 𝑥
# 𝑓
# (
# 𝑥
# )
# 𝑑
# 𝑥
# E[X]=∫xf(x)dx
#
# 23.How does a probability distribution relate to the expected outcome of a random variable?
#
# The probability distribution assigns probabilities to each possible outcome, and the expected outcome is the weighted average of these outcomes using those probabilities.
